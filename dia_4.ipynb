# %%
# Challenge 1

# Metodo 1
# informacion = {}
# cant_datos = int (input("Ingrese la cantidad de datos: "))
# for i in range (cant_datos):
#     clave_1 = input ("Que dato va a ingresar: ")
#     info_1 = input (f"Ingrese {clave_1}: ")
#     informacion[clave_1] = info_1
#     print (f"{clave_1} : {informacion[clave_1]}")

# print (informacion)

# Metodo 2
# def informacion_personal (clave, valor):
#     informacion = {str(clave):valor}
#     for i in informacion:
#         print (f"{clave}: {informacion[i]}")

# informacion = {}
# for i in range (4):
#     clave_1 = input ("Que dato desea cargar: ") 
#     info_1 = input(f"Ingrese {clave_1}: ")
#     informacion_personal (clave_1, info_1)
# Out:
# nombre: Lucas
# Apellido: Machuca
# edad: 24
# estatura: 1.75

# %%
#Challege 2
def agregar_dato(datos:dict):
    clave= input ("Que dato desea agregar?: ")
    info = input (f"Ingrese {clave}: ")
    print (f"Se agrego {clave}: {info}")
    datos[clave]= info

def modificar_dato(datos:dict):
    print (datos)
    clave = input ("Ingrese la llave que desea modificar: ")
    info = input ("Ingrese el nuevo valor: ")
    informacion [clave]= info
    print (f"Se modifico {clave}: {info}")

def eliminar_dato (datos:dict):
    print (datos)
    elim_dato = input ("Ingrese la llave a eliminar: ")
    del datos[elim_dato]
    print (datos)

def mostrar_lista (datos:dict):
    for i in datos:
        print (f"{i}: {datos[i]}\n")


informacion = { 'Nombre': 'Lucas', 
                'Apellido': 'Machuca',
                'Edad': 24}
salir = False 
while not salir:
    print ("""***   MENU    ***    
1. Mostar la Lista
2. Agregar nuevo elemento.
3. Modificar Elemento.
4. Eliminar Elemento. 
5. Salir """)

    opcion= int (input ("Ingrese la opcion que desea seleccionar: "))

    if opcion==1:
        mostrar_lista (informacion)
    
    elif opcion==2:
        agregar_dato (informacion)
    
    elif opcion==3:
        modificar_dato (informacion)
    
    elif opcion==4:
        eliminar_dato(informacion)

    elif opcion==5:
        print ("Se cerro el menu ")
        salir= True

    else:
        print ("Error!! Se ingreso una opcion incorrecta ") 



# print (informacion)

# agregar_dato (informacion)
# print (informacion)

# modificar_dato (informacion)
# print (informacion)

# eliminar_dato(informacion)
# print (informacion)

# %%
# Challenge 3 

def crear_contacto(datos:list):
    nombre= input ("Ingrese nombre: ")
    apellido = input (f"Ingrese apellido: ")
    celular = int (input("Ingrese telefono: "))
    nuevo_contacto = {'nombre': nombre, 'apellido':apellido, 'celular':celular}
    datos.append (nuevo_contacto)
    print (f"El nuevo contacto añadido es: \n{nuevo_contacto}")

def modificar_contacto(datos:dict):
    for i in range(len(datos)):
        print (f"""Id: {i+1} 
        {datos[i]}\n""")
    
    id_modificar = int (input("Ingrese el id a modificar "))
    datos [id_modificar-1]['nombre']= input ('ingrese el nuevo nombre: ')
    datos [id_modificar-1]['apellido']=  input ("Ingrese el nuevo apellido: ")
    datos [id_modificar-1]['celular']= input ("Ingrese el nuevo celular: ")
    print (f"""Se modifico el contacto con id: {id_modificar}
{datos[id_modificar-1]}""")

def eliminar_contacto (datos:list):
    id_eliminar = int (input("Ingrese la id a eliminar: "))
    contacto_eliminado= datos[id_eliminar]
    print (f"El contacto eliminado es: \n{contacto_eliminado}\n")
    datos.pop(id_eliminar)

def mostrar_lista (datos:list):
    for i in range(len(datos)):
        print (f"""Id: {i+1} 
{datos[i]}\n""")

lista_contactos =[{'nombre': 'Adrian', 'apellido': 'Echeverria', 'celular': 98745125},
                  {'nombre': 'Bruce', 'apellido': 'Wayne', 'celular': 98465198},
                  {'nombre': 'Steve', 'apellido': 'Rogers', 'celular': 651984541},
                  {'nombre': 'Tony', 'apellido':'Stark', 'celular': 68495689}]

salir = False 
while not salir:
    print ("""***   MENU    ***    
1. Mostar contactos.
2. Crear Contacto.
3. Modificar Contacto.
4. Eliminar Contacto. 
5. Salir """)

    opcion= int (input ("Ingrese la opcion que desea seleccionar: "))

    if opcion==1:
        mostrar_lista (lista_contactos)
    
    elif opcion==2:
         crear_contacto (lista_contactos)
    
    elif opcion==3:
        modificar_contacto (lista_contactos)
    
    elif opcion==4:
        eliminar_contacto(lista_contactos)

    elif opcion==5:
        print ("Se cerro el menu ")
        salir= True

    else:
        print ("Error!! Se ingreso una opcion incorrecta ")
