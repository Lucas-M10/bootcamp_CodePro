# %%
# Challenge 1
def imprimir_palabra (frase):
    print (f"La frase o palabra es: {frase}")

frase_imprimir = "tengo suenho Zzz."
palabra= input ("Ingrese la palabra: ")
imprimir_palabra (frase_imprimir)
imprimir_palabra (palabra)

# %%
#Challenge 2
def comparar_letras (primera_letra, segunda_letra):
    if primera_letra ==segunda_letra:
        print ("Las letras son iguales")
    else:
        print ("Las letras son diferentes")

comparar_letras("a", "a")
comparar_letras("a", "b")


# letra_1 = "a"
# letra_2 = "a"
# letra_3= "b"

# comparar_letras (letra_1, letra_2)
# comparar_letras (letra_1, letra_3)

# %%
# Ejemplo diferencia entre una funcion con return y sin return y solo print 
# def sumar_return (a, b):
#     return a+b
 
# def sumar_print (a, b):
#     print (f"la suma de a={a} y b={b} es igual a: {a+b}")

# resultado_1 = sumar_return (4, 8)
# resultado_2 = sumar_print (4, 8)

# print (resultado_1)
# print (resultado_2)
# #como la funcion sumar_print no devuelve el valor de la suma solo imrpime nos da None 

# Ejemplo del profesor 
# fondos = 1000
# def cajero (cantidad):
#     if fondos >= cantidad:
#         print (f"La cantidad de fondos es {fondos}")
#         #Aca esta el problema python interpreta que fondos es una variable local ya que se realiza una asignacion 
#         fondos-=cantidad <- Error 
#         return cantidad
#     else:
#         print ("Saldo insuficiente")

# aux = cajero (4_000)
# print (aux)
# Para solucionar el problema de que detecte fondos como variable local seria pasarle ese parametro a la funcion 

# Challenge 3 
def cantidad_caracteres (palabra:str, cant:int):
    if len(palabra)== cant:
        return True
    else:
        return False
    
# Metodo abreviado (compañero)
# Al hacer una comparacion ese directo devuelve una variable tipo booleano
def metodo_abreviado (palabra, cant):
    return len(palabra)==cant
    
resultado_1 = cantidad_caracteres ("hola", 4)
resultado_2 = cantidad_caracteres("buenos dias", 10)

resultado_3=metodo_abreviado("hola como estas", 4)

print (f"Metodo abreviado: {resultado_3}")
print (resultado_1)
print (resultado_2)
print (f"El resultado es {cantidad_caracteres('Hola como estas', 15)}")

# El error que me estaba dando es cuando hacemos de esta manera 
# print (f"{cantidad_caracteres("Hola como estas", 15)}") ERROR
# Ya que f-string empieza con una " y cuando ve "Hola como estas" piensa que ahi termina el string


lista_numeros = list  ("Hipopotamo") #Itera sobre el string 
print (lista_numeros)

# %%
# lista_numeros = list  ("Hipopotamo") #Itera sobre el string 
# print (lista_numeros)

#Challenge 4 (Metodo de funciones)
# Creo una lista vacia donde voy a ir agregando las palabras que se van separando
lista_palabras = [] 
# Creo la funcion que realiza la separacion y el que agrega a la lista que vamos a imprimir 
def crear_lista_palabra (palabra:str): 
    aux = list(palabra) 
    lista_palabras.append (aux)
    # for i in lista_palabras:
    #     print (f"{i}\n")
    print (lista_palabras)

palabra_1= input ("Ingrese la primer palabra: ")
crear_lista_palabra (palabra_1)

palabra_2= input ("Ingrese la segunda palabra: ")
crear_lista_palabra (palabra_2)

palabra_3= input ("Ingrese la tercera palabra: ")
crear_lista_palabra (palabra_3)

# %%
# Challenge 4 (Metodo con bucle)
lista_palabras = []
for i in range (3):
    palabra = input ("Ingrese la palabra: ")
    aux= list (palabra)
    lista_palabras.append (aux)
    print (lista_palabras)

# Challenge 4 (Pidiendole al usuario cuantas palbras hay)
lista_palabras = []
cant = int (input ("Ingrese la cantidad de palabra: "))
for i in range (cant):
    palabra = input ("Ingrese la palabra: ")
    aux= list(palabra)
    lista_palabras.append (aux)
    print (lista_palabras)

# %%
#Challenge 5
def imprimir_lista (lista):
    for i in range (len(lista)):
        print (lista[i])

lista_1 =  [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

imprimir_lista (lista_1)
